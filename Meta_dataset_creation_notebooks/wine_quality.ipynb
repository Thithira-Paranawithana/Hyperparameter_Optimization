# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
data = pd.read_csv("wine.csv")

# %%
data.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol quality
# 0      9.4     bad
# 1      9.8     bad
# 2      9.8     bad
# 3      9.8    good
# 4      9.4     bad

# %%
data.duplicated().sum()
# Out:
# 240

# %%
data = data.drop_duplicates()

# %%
data.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
data.shape
# Out:
# (1359, 12)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1359 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1359 non-null   float64
#  1   volatile acidity      1359 non-null   float64
#  2   citric acid           1359 non-null   float64
#  3   residual sugar        1359 non-null   float64
#  4   chlorides             1359 non-null   float64
#  5   free sulfur dioxide   1359 non-null   float64
#  6   total sulfur dioxide  1359 non-null   float64
#  7   density               1359 non-null   float64
#  8   pH                    1359 non-null   float64
#  9   sulphates             1359 non-null   float64
#  10  alcohol               1359 non-null   float64
#  11  quality               1359 non-null   object
# dtypes: float64(11), object(1)
# memory usage: 138.0+ KB

# %%
data.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1359.000000       1359.000000  1359.000000     1359.000000
# mean        8.310596          0.529478     0.272333        2.523400
# std         1.736990          0.183031     0.195537        1.352314
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.430000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1359.000000          1359.000000           1359.000000  1359.000000
# mean      0.088124            15.893304             46.825975     0.996709
# std       0.049377            10.447270             33.408946     0.001869
# min       0.012000             1.000000              6.000000     0.990070
# 25%       0.070000             7.000000             22.000000     0.995600
# 50%       0.079000            14.000000             38.000000     0.996700
# 75%       0.091000            21.000000             63.000000     0.997820
# max       0.611000            72.000000            289.000000     1.003690
#
#                 pH    sulphates      alcohol
# count  1359.000000  1359.000000  1359.000000
# mean      3.309787     0.658705    10.432315
# std       0.155036     0.170667     1.082065
# min       2.740000     0.330000     8.400000
# 25%       3.210000     0.550000     9.500000
# 50%       3.310000     0.620000    10.200000
# 75%       3.400000     0.730000    11.100000
# max       4.010000     2.000000    14.900000

# %%
data['quality'].value_counts()
# Out:
# quality
# good    719
# bad     640
# Name: count, dtype: int64

# %%
data.hist("fixed acidity")
# Out:
# array([[<Axes: title={'center': 'fixed acidity'}>]], dtype=object)

# %%
data.hist("volatile acidity")
# Out:
# array([[<Axes: title={'center': 'volatile acidity'}>]], dtype=object)

# %%
data.hist("citric acid")
# Out:
# array([[<Axes: title={'center': 'citric acid'}>]], dtype=object)

# %%
data.hist("density")
# Out:
# array([[<Axes: title={'center': 'density'}>]], dtype=object)

# %%
# shuffle data
data = data.sample(frac=1)
data = data.reset_index(drop=True)  # reet index after shuffling

# %%
data.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.7              0.62         0.04             3.8      0.084
# 1            7.1              0.43         0.17             1.8      0.082
# 2            6.1              0.38         0.15             1.8      0.072
# 3            8.7              0.52         0.09             2.5      0.091
# 4           10.8              0.29         0.42             1.6      0.084
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 25.0                  45.0  0.99780  3.34       0.53
# 1                 27.0                  51.0  0.99634  3.49       0.64
# 2                  6.0                  19.0  0.99550  3.42       0.57
# 3                 20.0                  49.0  0.99760  3.34       0.86
# 4                 19.0                  27.0  0.99545  3.28       0.73
#
#    alcohol quality
# 0      9.5     bad
# 1     10.4     bad
# 2      9.4     bad
# 3     10.6    good
# 4     11.9    good

# %%
X = data.drop('quality', axis=1) # use all columns except 'target' as features
Y = data['quality']

# %%
X.shape, Y.shape
# Out:
# ((1359, 11), (1359,))

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.metrics import accuracy_score

# %%
# Split the data into training and testing sets
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.25, random_state=42)

# %%
param_grid = {
    'n_estimators': [25, 50, 75, 100, 150],         # Focus on fewer trees due to dataset size
    'max_depth': [3, 5, 7, 10, 50],         # Explore shallow and fully grown trees
    'max_features': ['sqrt', 'log2'],     # Use subsets of features for splits
    'min_samples_split': [2, 5, 10]       # Control node splits
}

# %%
# Initialize the Random Forest Classifier
rf_model = RandomForestClassifier(random_state=42)

# %%
# Set up GridSearchCV
grid_search = GridSearchCV(estimator=rf_model, param_grid=param_grid, cv=3, scoring='accuracy', verbose=1)

# %%
# Perform Grid Search
grid_search.fit(X_train, Y_train)
# Out:
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# GridSearchCV(cv=3, estimator=RandomForestClassifier(random_state=42),
#              param_grid={'max_depth': [3, 5, 7, 10, 50],
#                          'max_features': ['sqrt', 'log2'],
#                          'min_samples_split': [2, 5, 10],
#                          'n_estimators': [25, 50, 75, 100, 150]},
#              scoring='accuracy', verbose=1)

# %%
# Extract results
results = pd.DataFrame(grid_search.cv_results_)

# %%
# Select relevant columns for meta-dataset
meta_dataset = results[['param_n_estimators', 'param_max_depth', 'param_max_features', 'param_min_samples_split',
                        'mean_test_score']]

# %%
# Rename columns for clarity
meta_dataset.rename(columns={
    'param_n_estimators': 'n_estimators',
    'param_max_depth': 'max_depth',
    'param_max_features': 'max_features',
    'param_min_samples_split': 'min_samples_split',
    'mean_test_score': 'accuracy'
}, inplace=True)
# Out:
# <ipython-input-31-584a53431e15>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   meta_dataset.rename(columns={

# %%
# Add meta-features of the dataset
meta_features = {
    'num_features': X.shape[1],
    'num_samples': X.shape[0],
    'class_imbalance_ratio': Y.value_counts().max() / Y.value_counts().min(),
    'num_classes': len(Y.unique())
}

# %%
for feature, value in meta_features.items():
    meta_dataset[feature] = value
# Out:
# <ipython-input-33-efeef45cdee3>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   meta_dataset[feature] = value
# <ipython-input-33-efeef45cdee3>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   meta_dataset[feature] = value
# <ipython-input-33-efeef45cdee3>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   meta_dataset[feature] = value
# <ipython-input-33-efeef45cdee3>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   meta_dataset[feature] = value

# %%
# Display the meta-dataset
print(meta_dataset.head())
# Out:
#    n_estimators  max_depth max_features  min_samples_split  accuracy  \
# 0            25          3         sqrt                  2  0.746793
# 1            50          3         sqrt                  2  0.753664
# 2            75          3         sqrt                  2  0.748762
# 3           100          3         sqrt                  2  0.751703
# 4           150          3         sqrt                  2  0.750726
#
#    num_features  num_samples  class_imbalance_ratio  num_classes
# 0            11         1359               1.123438            2
# 1            11         1359               1.123438            2
# 2            11         1359               1.123438            2
# 3            11         1359               1.123438            2
# 4            11         1359               1.123438            2

# %%
# Save the meta-dataset to a CSV file for later use
meta_dataset.to_csv('meta_dataset_wine.csv', index=False)
