# %%
import numpy as np
import pandas as pd

import os
for dirname, _, filenames in os.walk('/content/abc'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /content/abc/test.csv
# /content/abc/train.csv

# %%
train_data = pd.read_csv("/content/abc/train.csv")
train_data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
test_data = pd.read_csv("/content/abc/test.csv")
test_data.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
train_data.shape
# Out:
# (891, 12)

# %%
test_data.shape
# Out:
# (418, 11)

# %%
women = train_data.loc[train_data.Sex == 'female']["Survived"]
rate_women = sum(women)/len(women)

print("% of women who survived:", rate_women)
# Out:
# % of women who survived: 0.7420382165605095

# %%
men = train_data.loc[train_data.Sex == 'male']["Survived"]
rate_men = sum(men)/len(men)

print("% of men who survived:", rate_men)
# Out:
# % of men who survived: 0.18890814558058924

# %%
train_data.isnull()
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 886        False     False   False  False  False  False  False  False   False
# 887        False     False   False  False  False  False  False  False   False
# 888        False     False   False  False  False   True  False  False   False
# 889        False     False   False  False  False  False  False  False   False
# 890        False     False   False  False  False  False  False  False   False
#
#       Fare  Cabin  Embarked
# 0    False   True     False
# 1    False  False     False
# 2    False   True     False
# 3    False  False     False
# 4    False   True     False
# ..     ...    ...       ...
# 886  False   True     False
# 887  False  False     False
# 888  False   True     False
# 889  False  False     False
# 890  False   True     False
#
# [891 rows x 12 columns]

# %%
len(train_data)
# Out:
# 891

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
sns.countplot(x="Survived", data=train_data)
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
sns.countplot(x="Survived", hue="Sex", data=train_data)
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
train_data.hist("Age")
# Out:
# array([[<Axes: title={'center': 'Age'}>]], dtype=object)

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
train_data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
train_data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
train_data.drop("Cabin", axis=1, inplace=True)

# %%
train_data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Embarked'],
#       dtype='object')

# %%
train_data.dropna(inplace=True)

# %%
train_data.shape
# Out:
# (712, 11)

# %%
train_data.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %%
sex = pd.get_dummies(train_data["Sex"], drop_first=True)

# %%
sex.head()
# Out:
#     male
# 0   True
# 1  False
# 2  False
# 3  False
# 4   True

# %%
embark = pd.get_dummies(train_data["Embarked"], drop_first=True)

# %%
embark.head()
# Out:
#        Q      S
# 0  False   True
# 1  False  False
# 2  False   True
# 3  False   True
# 4  False   True

# %%
pclass = pd.get_dummies(train_data["Pclass"], drop_first=True)

# %%
pclass.head()
# Out:
#        2      3
# 0  False   True
# 1  False  False
# 2  False   True
# 3  False  False
# 4  False   True

# %%
train_data = pd.concat([train_data, sex, embark, pclass], axis=1)

# %%
train_data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Embarked   male      Q      S      2  \
# 0      0         A/5 21171   7.2500        S   True  False   True  False
# 1      0          PC 17599  71.2833        C  False  False  False  False
# 2      0  STON/O2. 3101282   7.9250        S  False  False   True  False
# 3      0            113803  53.1000        S  False  False   True  False
# 4      0            373450   8.0500        S   True  False   True  False
#
#        3
# 0   True
# 1  False
# 2   True
# 3  False
# 4   True

# %%
train_data.drop(["Sex", "Embarked", "Name", "PassengerId", "Pclass", "Ticket"], axis=1, inplace=True)

# %%
train_data = train_data.replace({True: 1, False: 0})
# Out:
# <ipython-input-31-dbb880b83922>:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   train_data = train_data.replace({True: 1, False: 0})

# %%
train_data.head()
# Out:
#    Survived   Age  SibSp  Parch     Fare  male  Q  S  2  3
# 0         0  22.0      1      0   7.2500     1  0  1  0  1
# 1         1  38.0      1      0  71.2833     0  0  0  0  0
# 2         1  26.0      0      0   7.9250     0  0  1  0  1
# 3         1  35.0      1      0  53.1000     0  0  1  0  0
# 4         0  35.0      0      0   8.0500     1  0  1  0  1

# %%
X = train_data.drop("Survived", axis=1)
Y = train_data["Survived"]

# %%
X.shape, Y.shape
# Out:
# ((712, 9), (712,))

# %%
train_data.loc[train_data.Survived == 1]
# Out:
#      Survived   Age  SibSp  Parch     Fare  male  Q  S  2  3
# 1           1  38.0      1      0  71.2833     0  0  0  0  0
# 2           1  26.0      0      0   7.9250     0  0  1  0  1
# 3           1  35.0      1      0  53.1000     0  0  1  0  0
# 8           1  27.0      0      2  11.1333     0  0  1  0  1
# 9           1  14.0      1      0  30.0708     0  0  0  1  0
# ..        ...   ...    ...    ...      ...   ... .. .. .. ..
# 875         1  15.0      0      0   7.2250     0  0  0  0  1
# 879         1  56.0      0      1  83.1583     0  0  0  0  0
# 880         1  25.0      0      1  26.0000     0  0  1  1  0
# 887         1  19.0      0      0  30.0000     0  0  1  0  0
# 889         1  26.0      0      0  30.0000     1  0  0  0  0
#
# [288 rows x 10 columns]

# %%
train_data.loc[train_data.Survived == 0]
# Out:
#      Survived   Age  SibSp  Parch     Fare  male  Q  S  2  3
# 0           0  22.0      1      0   7.2500     1  0  1  0  1
# 4           0  35.0      0      0   8.0500     1  0  1  0  1
# 6           0  54.0      0      0  51.8625     1  0  1  0  0
# 7           0   2.0      3      1  21.0750     1  0  1  0  1
# 12          0  20.0      0      0   8.0500     1  0  1  0  1
# ..        ...   ...    ...    ...      ...   ... .. .. .. ..
# 883         0  28.0      0      0  10.5000     1  0  1  1  0
# 884         0  25.0      0      0   7.0500     1  0  1  0  1
# 885         0  39.0      0      5  29.1250     0  1  0  0  1
# 886         0  27.0      0      0  13.0000     1  0  1  1  0
# 890         0  32.0      0      0   7.7500     1  1  0  0  1
#
# [424 rows x 10 columns]

# %%
# shuffle data
train_data = train_data.sample(frac=1)
train_data = train_data.reset_index(drop=True)  # reet index after shuffling

# %%
train_data.head()
# Out:
#    Survived   Age  SibSp  Parch     Fare  male  Q  S  2  3
# 0         1  36.0      0      0  13.0000     0  0  1  1  0
# 1         0   2.0      4      2  31.2750     0  0  1  0  1
# 2         0  11.0      4      2  31.2750     0  0  1  0  1
# 3         1  36.0      0      0  26.3875     1  0  1  0  0
# 4         0  43.0      1      6  46.9000     0  0  1  0  1

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.metrics import accuracy_score

# %%
# Split the data into training and testing sets
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.25, random_state=42)

# %%
X_train.columns = X_train.columns.astype(str)

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 534 entries, 703 to 131
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Age     534 non-null    float64
#  1   SibSp   534 non-null    int64
#  2   Parch   534 non-null    int64
#  3   Fare    534 non-null    float64
#  4   male    534 non-null    int64
#  5   Q       534 non-null    int64
#  6   S       534 non-null    int64
#  7   2       534 non-null    int64
#  8   3       534 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 41.7 KB

# %%
param_grid = {
    'n_estimators': [25, 50, 75, 100],       # Balanced number of trees for quick training and sufficient diversity.
    'max_depth': [3, 5, 7, 10],       # Shallow to fully grown trees for flexibility.
    'max_features': ['sqrt', 'log2'],   # Subsets of features to prevent overfitting.
    'min_samples_split': [2, 5, 10],    # Fine-to-coarse splits based on dataset size.
    'class_weight': ['balanced']        # Adjust weights to handle the slight imbalance.
}

# %%
# Initialize the Random Forest Classifier
rf_model = RandomForestClassifier(random_state=42)

# %%
# Set up GridSearchCV
grid_search = GridSearchCV(estimator=rf_model, param_grid=param_grid, cv=3, scoring='accuracy', verbose=1)

# %%
# Perform Grid Search
grid_search.fit(X_train, Y_train)
# Out:
# Fitting 3 folds for each of 96 candidates, totalling 288 fits
# GridSearchCV(cv=3, estimator=RandomForestClassifier(random_state=42),
#              param_grid={'class_weight': ['balanced'],
#                          'max_depth': [3, 5, 7, 10],
#                          'max_features': ['sqrt', 'log2'],
#                          'min_samples_split': [2, 5, 10],
#                          'n_estimators': [25, 50, 75, 100]},
#              scoring='accuracy', verbose=1)

# %%
# Extract results
results = pd.DataFrame(grid_search.cv_results_)

# %%
# Select relevant columns for meta-dataset
meta_dataset = results[['param_n_estimators', 'param_max_depth', 'param_max_features', 'param_min_samples_split',
                        'mean_test_score']]

# %%
# Rename columns for clarity
meta_dataset.rename(columns={
    'param_n_estimators': 'n_estimators',
    'param_max_depth': 'max_depth',
    'param_max_features': 'max_features',
    'param_min_samples_split': 'min_samples_split',
    'mean_test_score': 'accuracy'
}, inplace=True)
# Out:
# <ipython-input-49-584a53431e15>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   meta_dataset.rename(columns={

# %%
# Add meta-features of the dataset
meta_features = {
    'num_features': X.shape[1],
    'num_samples': X.shape[0],
    'class_imbalance_ratio': Y.value_counts().max() / Y.value_counts().min(),
    'num_classes': len(Y.unique())
}

# %%
for feature, value in meta_features.items():
    meta_dataset[feature] = value
# Out:
# <ipython-input-51-efeef45cdee3>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   meta_dataset[feature] = value
# <ipython-input-51-efeef45cdee3>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   meta_dataset[feature] = value
# <ipython-input-51-efeef45cdee3>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   meta_dataset[feature] = value
# <ipython-input-51-efeef45cdee3>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   meta_dataset[feature] = value

# %%
# Display the meta-dataset
print(meta_dataset.head())
# Out:
#    n_estimators  max_depth max_features  min_samples_split  accuracy  \
# 0            25          3         sqrt                  2  0.777154
# 1            50          3         sqrt                  2  0.775281
# 2            75          3         sqrt                  2  0.767790
# 3           100          3         sqrt                  2  0.773408
# 4            25          3         sqrt                  5  0.773408
#
#    num_features  num_samples  class_imbalance_ratio  num_classes
# 0             9          712               1.472222            2
# 1             9          712               1.472222            2
# 2             9          712               1.472222            2
# 3             9          712               1.472222            2
# 4             9          712               1.472222            2

# %%
# Save the meta-dataset to a CSV file for later use
meta_dataset.to_csv('meta_dataset_titanic.csv', index=False)
